# %% [markdown]
# ## 新聞爬蟲

# %%
# !pip install selenium -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\user\appdata\roaming\python\python39\site-packages (4.8.3)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\user\appdata\roaming\python\python39\site-packages (from selenium) (1.26.15)
# Requirement already satisfied: trio~=0.17 in c:\users\user\appdata\roaming\python\python39\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\user\appdata\roaming\python\python39\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\user\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\user\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in c:\users\user\appdata\roaming\python\python39\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %% [markdown]
# ## [Download Chrome Driver](https://sites.google.com/chromium.org/driver/)

# %%
from selenium import webdriver
import sys
import time

# %% [markdown]
# ## 參數設定

# %%
url='https://news.ltn.com.tw/topic/台灣' # 自由時報
scroll_times = 10 # scroll down 次數

# %%
# Chrome 參數
options = webdriver.ChromeOptions()
# 不載入圖片，加速網頁擷取
prefs = {
    'profile.default_content_setting_values' : {
        'images' : 2
    }
}
options.add_argument('headless')
options.add_experimental_option('prefs',prefs)
driver = webdriver.Chrome(options = options)

# %%
# scroll down 10 次
driver.get(url)
for i in range(scroll_times):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)

# %%
from selenium.webdriver.common.by import By

data=''
for item in driver.find_elements(By.CSS_SELECTOR, 'a.tit'):
#     if item.text.strip() == '' or item.text.strip().startswith('三立')          or item.text.strip().startswith('聯合') or item.text.strip().startswith('中時')          or item.text.strip().startswith('自由時報') or item.text.strip().startswith('新頭殼')          or item.text.strip().startswith('公視新聞網') or item.text.strip().startswith('電腦王阿達')          or item.text.strip().startswith('udn') or item.text.strip().startswith('NOWnews')          or item.text.strip().startswith('中天') or item.text.strip().startswith('ETtoday')          or item.text.strip().startswith('Yahoo') or item.text.strip().startswith('查看完整報導'):
#         continue       
    print(item.text)
    data += item.text + '\n'
# Out:
# 中宏建交與豔星有關？彭丹自爆促進中宏商業往來立功
# 學者：台灣符CPTPP高標準規範 應可比中國先加入
# 台灣未來由台灣人民決定！加拿大國會公布「台灣報告書」
# 英國入CPTPP 日媒：下一個是台灣
# 海纜修復 台灣馬祖通信恢復
# 政院︰英國入CPTPP是參考典範 我續做好準備
# 菜市場政治學》轉型中的臺灣援外：從「建交為本」到「以人為本」＆改革的啟動
# 自由開講》台宏斷交凸顯中美衝突更為嚴峻
# 正國會民調：逾6成受訪者認同 蔡英文出訪助台灣提升國際地位
# 英將加入CPTPP 日媒：下個會是台灣嗎？
# 馬稱德法世仇能化解為何兩岸不能？律師列8條件戳破盲點
# 社論》台灣要堅定走向世界
# 2023全球最佳醫療照護城市排名出爐 北高並列全球第一！
# 社論》台灣與美中關係升降的連動性
# 知名統計網站公布2023最幸福國家！這國蟬聯6年 台灣亞洲第4
# 胡，怎麼說》馬英九在中國的「統戰殘值」，只剩「這個」！
# 一句「高雄墾丁」識破詐騙菜鳥 網譏：再騙啊
# 德國女孩點出9大台灣奇葩文化 網友：無法反駁
# 社論》中美衝突結構與台灣兩條路線
# 捷克眾議長艾達莫娃向中國喊話：進犯台灣必將失敗
# 對等原則辦理 我要求宏國30日內撤館
# 秀新世代伺服器 和碩：台灣是全球好夥
# 新聞360》告別「依賴中國」成共識？揭德國劃世代覺醒關鍵
# 台灣捐物資400噸 土耳其「足感心」
# 經部：Chip4工作會議已召開 聚焦設計「預警機制」
# 民調：69％認為中國對台灣威脅嚴重 台美關係重於兩岸關係
# 前白宮國安顧問呼籲美承認台灣 軍艦停靠高雄
# 增加駐軍是個開始... 龐皮歐：應承認台灣為自由主權國家
# Netflix證實亞太市場部分降價 不包含台灣
# 美眾院中國特委會28日首開聽證 邀4重量級證人
# 日智庫兵推中國2026侵台戰爭估2週結束 共軍傷亡逾4萬人
# 日本人氣AV女優來台宣傳 打卡PO文驚見 「一大堆蛋蛋照」！
# 胡，怎麼說》尼布楚再現江湖，習近平應向普廷索還中國失土！
# 旅遊網紅Drew Binsky來台 夜市、溫泉、原住民景點玩透透
# 傳美擴增駐台美軍 白宮重申：對台防務支持不變
# 台海危機非中國內政 布林肯：對全球經濟有毀滅性後果
# 因應中國威脅 華爾街日報：駐台美軍將擴增4倍
# 台灣力挺烏克蘭 烏國政界輿論熱議赴台設代表處

# %%
# close chrome
driver.quit()

# %%
# save file
with open('./news.txt', 'w', encoding='utf8') as f:
    f.write(data)

# %% [markdown]
# ## 中文文字雲

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import jieba
import jieba.analyse
from collections import Counter # 次數統計

dictfile = "./dict.txt"  # 字典檔
stopfile = "./stopwords.txt"  # stopwords
fontpath = "C:\Windows\Fonts\msjh.ttc"  # 字型檔 (注意副檔名要標,否則於電腦 C 槽內 c:\Windows\Fonts 直接尋找字型檔會錯誤;或是直接將檔案複製到 .ipynb 所屬資料夾內,直接尋找檔案即可)

mdfile = "./news.txt"  # 文檔
pngfile = "./mask_0401.png"  # 剛才下載存的底圖

alice_mask = np.array(Image.open(pngfile))

jieba.set_dictionary(dictfile)
jieba.analyse.set_stop_words(stopfile)

text = open(mdfile,"r",encoding="utf-8").read()

tags = jieba.analyse.extract_tags(text, topK=25)

seg_list = jieba.lcut(text, cut_all=False)
dictionary = Counter(seg_list)

freq = {}
for ele in dictionary:
    if ele in tags:
        freq[ele] = dictionary[ele]
print(freq) # 計算出現的次數

wordcloud = WordCloud(background_color="pink", mask=alice_mask, contour_width=3, contour_color='steelblue', font_path= fontpath).generate_from_frequencies(freq)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Building prefix dict from D:\Python\Python3\Class 12\HW6 文字雲\dict.txt ...
# Loading model from cache C:\Users\User\AppData\Local\Temp\jieba.u1207e56e574589ab05cbbf5120183881.cache
# Loading model cost 0.799 seconds.
# Prefix dict has been built successfully.
# {'建交': 8, '台灣': 94, 'CPTPP': 6, '中國': 54, '英國': 6, '自由': 20, '開講': 14, '台宏': 11, '斷交': 10, '國際': 6, '關係': 10, '國家': 7, '亞洲': 7, '德國': 8, '議長': 8, '宏國': 6, '民主': 10, '宏都拉斯': 11, '中共': 9, '總統': 8, '外交': 11, '眾院': 8, '對台': 7, '智庫': 7, '威脅': 6}
